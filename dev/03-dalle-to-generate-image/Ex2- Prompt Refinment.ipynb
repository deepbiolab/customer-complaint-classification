# %%
# Important: Don't forget to update this

AZURE_OPENAI_API_KEY = ""
AZURE_OPENAI_ENDPOINT = ""

GPT_DEPLOYMENT = ""
GPT_VERSION = ""
DALLE_DEPLOYMENT = ""
DALLE_VERSION = ""

# %%
import requests
from PIL import Image
from IPython.display import display

from utils import create_openai_client, generate_image

# %%
dalle = create_openai_client(DALLE_VERSION, AZURE_OPENAI_API_KEY, AZURE_OPENAI_ENDPOINT)

# %%
prompt = "Create a warm and nostalgic still-life photograph of a golden-brown cookie placed on a soft napkin. The composition should feature an eye-level perspective with a shallow depth of field. The cookie is sharply in focus in the foreground, while the background is blurred with a creamy bokeh effect. Include a glass jar with additional cookies in the background, softly lit. Use warm, earthy tones, and emphasize the texture of the cookie and napkin. The lighting should be harsh and directional, creating contrast and soft shadows for a cozy, vintage feel."

# %%
image_url = generate_image(
    dalle, prompt, DALLE_DEPLOYMENT, '1024x1024', 'hd', 'natural')
image_url
# Out:
# 'https://dalleproduse.blob.core.windows.net/private/images/ab54ad96-1f2a-443b-94ad-eeda6f417e2c/generated_00.png?se=2024-11-24T11%3A50%3A11Z&sig=U3a2dSgmcGfAyP1ZaETL03cCgEGPMmQu1y1R4KuuIPc%3D&ske=2024-11-29T14%3A47%3A57Z&skoid=09ba021e-c417-441c-b203-c81e5dcd7b7f&sks=b&skt=2024-11-22T14%3A47%3A57Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02'

# %%
Image.open(requests.get(image_url, stream=True).raw)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
refined_prompt = """
cookies brand, keep it simple and minimal. no text. show macro focus on cookie kept on a tissue over a table and a jar of cookies to the side"""

# %%
image_url = generate_image(
    dalle, refined_prompt, DALLE_DEPLOYMENT, '1024x1024', 'hd', 'natural')
Image.open(requests.get(image_url, stream=True).raw)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
